# %% [markdown]
# <a href="https://colab.research.google.com/github/hongminh25/Project-new/blob/master/yolov6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#clone mã nguồn
# %cd /content/drive/MyDrive/yolov6
# !git clone https://github.com/meituan/YOLOv6.git

# %%
#Cai dat thu vien
# %cd /content/drive/MyDrive/yolov6/YOLOv6
# !pip install -r requirements.txt

# %%
# Kiem tra viec cai dat
import torch
torch.cuda.is_available()
torch.cuda.get_device_name()
# Out:
# 'Tesla T4'

# %%
# Tai anh tren google ve de thu nghiem nhan dien
# %cd /content/drive/MyDrive/yolov6
# !mkdir test_images
# %cd test_images
# !wget https://cdn.theculturetrip.com/wp-content/uploads/2017/11/15271255494_fcc90d3f9b_k.jpg

# %%
# Thu nhan dien voi pretrain weights
# %cd /content/drive/MyDrive/yolov6/YOLOv6
# !python tools/infer.py --weights /content/drive/MyDrive/yolov6/YOLOv6/yolov6s.pt --source /content/drive/MyDrive/yolov6/test_images/15271255494_fcc90d3f9b_k.jpg

# %%
# Giai nen tep firedata.zip
# %cd /content/drive/MyDrive/yolov6
# !mkdir train_images
# %cd train_images
# !unzip ../firedata.zip

# %%
#To chuc lai
# %cd /content/drive/MyDrive/yolov6/train_images
# !mkdir images
# !mkdir images/train

# !mv *.jpg images/train

# !mkdir labels
# !mkdir labels/train

# !mv *.txt labels/train

#Tao file val va test cho images
# %cd /content/drive/MyDrive/yolov6/train_images/images
# !mkdir val
# %cp train/*.jpg val

# %cd /content/drive/MyDrive/yolov6/train_images/images
# !mkdir test
# %cp train/*.jpg test
#Tao file val,test cho labels
# %cd /content/drive/MyDrive/yolov6/train_images/labels
# !mkdir val
# %cp train/*.txt val
# %cd /content/drive/MyDrive/yolov6/train_images/labels
# !mkdir test
# %cp train/*.txt test

# %% [markdown]
# Labels

# %%
#Tao file val,test cho labels
# %cd /content/drive/MyDrive/yolov6/train_images/labels
# !mkdir val
# %cp train/*.txt val
# %cd /content/drive/MyDrive/yolov6/train_images/labels
# !mkdir test
# %cp train/*.txt test

# %%
# Tao Yaml de cho YOLOv6 biet foler train, folder val va so class, tên class
# %cd /content/drive/MyDrive/yolov6/YOLOv6
# !rm data/mydataset.yaml
# !echo 'train: ../train_images/images/train' >> data/mydataset.yaml
# !echo 'val: ../train_images/images/train' >> data/mydataset.yaml
# !echo 'is_coco: False' >> data/mydataset.yaml
# !echo 'nc: 0' >> data/mydataset.yaml
# !echo "names: ['fire']" >> data/mydataset.yaml
# Out:
# /content/drive/MyDrive/yolov6/YOLOv6

# %%
# %cd /content/drive/MyDrive/yolov6/YOLOv6
# Be sure to open use_dfl mode in config file (use_dfl=True, reg_max=16) if you want to do self-distillation training further.
# !python tools/train.py --batch 32 --conf /content/drive/MyDrive/yolov6/YOLOv6/configs/yolov6s.py --data data/dataset.yaml --fuse_ab --device 0 --epochs 100
# Out:
# /content/drive/MyDrive/yolov6/YOLOv6
# 2023-09-13 07:12:05.737636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-13 07:12:06.652979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using 1 GPU for training...
# ...
